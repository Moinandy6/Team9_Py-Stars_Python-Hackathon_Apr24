# %% [markdown]
# # Find the patient's outcome who had high CCI Score

# %%
import pandas as pd
import numpy as np

# %%
df_PatientHistory=pd.read_excel("Cardiac_Outcomes.xlsx","PatientHistory")
df_Hospitalization_Discharge = pd.read_excel("Cardiac_Outcomes.xlsx","Hospitalization_Discharge")
import matplotlib.pyplot as plt
df_Demography=pd.read_excel("Cardiac_Outcomes.xlsx","Demography")
df_Labs=pd.read_excel("Cardiac_Outcomes.xlsx","Labs")

# %% [markdown]
# # Plot a bar chart showing the number of patients having typeII respiratory failure.

# %%
RespiratoryFailure_Type = df_PatientHistory["type_II_respiratory_failure"].value_counts().to_frame('count')
RespiratoryFailure_Type
# Out:
#                              count
# type_II_respiratory_failure
# NonTypeII                     1894
# TypeII                         114

# %%
Patients_Counts=df_PatientHistory["inpatient_number"]
RespiratoryFailure_Type = df_PatientHistory["type_II_respiratory_failure"]
plt.hist(RespiratoryFailure_Type, bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('RespiratoryFailure_Type')
plt.ylabel('Patients_Counts')
plt.title('RespiratoryFailure of Patients')
plt.show()

# %%
plt.xticks(range(0, len(admissions_count), 5), admissions_count.index[::5].strftime('%Y-%m'))

# %% [markdown]
# # Count of patients having Dementia as per gender

# %%
df1=df_Demography    
df2=df_PatientHistory
df_Merged=pd.merge(df1,df2)
df_Merged
df_grouped=df_Merged.groupby(['dementia','gender']).size().unstack()
df_grouped
# Out:
# gender    Female  Male
# dementia
# 0           1112   781
# 1             51    64

# %% [markdown]
# # Visualize correlation between systolic_blood_pressure and diastolic_blood_pressure as per gender

# %%
import seaborn as sns
s=df_Labs
h=df_Labs["systolic_blood_pressure"]
m=df_Labs["diastolic_blood_pressure"]
sns.scatterplot(data=s, x=h,y=m, hue=df_Demography["gender"])
# Out:
# <Axes: xlabel='systolic_blood_pressure', ylabel='diastolic_blood_pressure'>

# %% [markdown]
# # Q.Visualize CCI score as per gender

# %%
import seaborn as sns
f=df_PatientHistory["CCI_score"]
p=df_Demography["gender"]
sns.catplot(data=f, x=p, y=f ,kind='box')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32148\716689772.py in ?()
#       1 import seaborn as sns
#       2 f=df_PatientHistory["CCI_score"]
#       3 p=df_Demography["gender"]
# ----> 4 sns.catplot(data=f, x=p, y=f ,kind='box')
#
# ~\anaconda3\Lib\site-packages\seaborn\categorical.py in ?(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3240     # Initialize the facets
#    3241     g = FacetGrid(**facet_kws)
#    3242
#    3243     # Draw the plot onto the facets
# -> 3244     g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3245
#    3246     if p.orient == "h":
# ...

# %% [markdown]
# # Q-Visualize the admission_ward as per gender?

# %%
l=df_Hospitalization_Discharge["admission_ward"]
p=df_Demography["gender"]
sns.histplot(data=l, x=l,kde=True,hue=p,palette=['pink','blue'])
# Out:
# <Axes: xlabel='admission_ward', ylabel='Count'>
